# %% [markdown]
# # Jolpica Data EDA
#
# This notebook explores the new Jolpica F1 dataset structure loaded via the updated `F1DataRepository`.
#
# **Goals:**
# 1. Verify connection to the database.
# 2. Load the full race history using the new schema.
# 3. Check column names and data types.
# 4. Assess data quality (missing values).
# 5. Export sample data for inspection.

# %%
import sys
import os
from pathlib import Path
import pandas as pd

# # Add project root to sys.path to allow importing modules
project_root = Path(os.getcwd()).parent / 'src' / 'gonzo_pit_strategy'
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

from db.repositories.data_repository import F1DataRepository
from gonzo_pit_strategy.log.logger import get_logger

# Setup basic logging
logger = get_logger("eda_notebook")

# %% [markdown]
# ## 1. Load Race History
# Fetching data using the updated `get_all_race_history()` method which joins Rounds, Sessions, and Entries.

# %%
try:
    df = F1DataRepository.get_all_race_history()
    print(f"Successfully loaded data with shape: {df.shape}")
except Exception as e:
    print(f"Error loading data: {e}")
# Out:
# 2026-01-19 22:11:25,631 - gonzo_pit_strategy.security.vault - DEBUG - Successfully authenticated with Vault
# 2026-01-19 22:11:25,634 - gonzo_pit_strategy.security.vault - INFO - Vault client initialized successfully
# 2026-01-19 22:11:25,672 - gonzo_pit_strategy.db.connection_pool - INFO - Creating database engine for postgresql+psycopg2 at 10.0.20.18:5432/f1db
# 2026-01-19 22:11:25,825 - gonzo_pit_strategy.db.connection_pool - DEBUG - Database engine and session factory created successfully
# Successfully loaded data with shape: (25873, 29)

# %% [markdown]
# ## 2. Basic Structure Inspection

# %%
# Check column names and types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25873 entries, 0 to 25872
# Data columns (total 29 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   round_id                      25873 non-null  int64
#  1   circuit_id                    25873 non-null  int64
#  2   circuit_name                  25873 non-null  object
#  3   season_year                   25873 non-null  int64
#  4   round_date                    25873 non-null  object
#  5   round_number                  25873 non-null  int64
#  6   round_url                     25873 non-null  object
#  7   team_id                       25873 non-null  int64
#  8   team_name                     25873 non-null  object
#  9   driver_id                     25873 non-null  int64
#  10  driver_abbreviation           10644 non-null  object
#  11  q1_time                       0 non-null      object
#  12  q2_time                       0 non-null      object
#  13  q3_time                       0 non-null      object
#  14  qualifying_position           10850 non-null  float64
#  15  grid                          25873 non-null  int64
#  16  finish_position               25873 non-null  int64
#  17  status                        25873 non-null  int64
#  18  status_detail                 25873 non-null  object
#  19  laps_completed                25873 non-null  int64
#  20  points                        25873 non-null  float64
#  21  time                          8435 non-null   object
#  22  fastest_lap_rank              8986 non-null   float64
#  23  driver_championship_points    25873 non-null  float64
#  24  driver_championship_position  18883 non-null  float64
#  25  driver_wins                   25873 non-null  int64
#  26  team_championship_points      25545 non-null  float64
#  27  team_championship_position    20759 non-null  float64
#  28  team_wins                     25545 non-null  float64
# dtypes: float64(8), int64(11), object(10)
# memory usage: 5.7+ MB

# %%
# View first few rows
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    round_id  circuit_id         circuit_name  season_year  round_date  \
# 0         1           1  Silverstone Circuit         1950  1950-05-13
# 1         1           1  Silverstone Circuit         1950  1950-05-13
# 2         1           1  Silverstone Circuit         1950  1950-05-13
# 3         1           1  Silverstone Circuit         1950  1950-05-13
# 4         1           1  Silverstone Circuit         1950  1950-05-13
#
#    round_number                                          round_url  team_id  \
# 0             1  https://en.wikipedia.org/wiki/1950_British_Gra...        1
# 1             1  https://en.wikipedia.org/wiki/1950_British_Gra...        1
# 2             1  https://en.wikipedia.org/wiki/1950_British_Gra...        1
# 3             1  https://en.wikipedia.org/wiki/1950_British_Gra...        5
# 4             1  https://en.wikipedia.org/wiki/1950_British_Gra...        5
#
#      team_name  driver_id driver_abbreviation q1_time q2_time q3_time  \
# 0   Alfa Romeo          1                None    None    None    None
# 1   Alfa Romeo          2                None    None    None    None
# 2   Alfa Romeo          3                None    None    None    None
# 3  Talbot-Lago          4                None    None    None    None
# 4  Talbot-Lago          5                None    None    None    None
#
#    qualifying_position  grid  finish_position  status status_detail  \
# 0                  NaN     1                1       0      Finished
# 1                  NaN     2                2       0      Finished
# 2                  NaN     4                3       0      Finished
# 3                  NaN     6                4       1       +2 Laps
# 4                  NaN     9                5       1       +2 Laps
#
#    laps_completed  points        time  fastest_lap_rank  \
# 0              70     9.0  02:13:23.6               NaN
# 1              70     6.0  02:13:26.2               NaN
# 2              70     4.0  02:14:15.6               NaN
# 3              68     3.0        None               NaN
# 4              68     2.0        None               NaN
#
#    driver_championship_points  driver_championship_position  driver_wins  \
# 0                         9.0                           1.0            1
# 1                         6.0                           2.0            0
# 2                         4.0                           3.0            0
# 3                         3.0                           4.0            0
# 4                         2.0                           5.0            0
#
#    team_championship_points  team_championship_position  team_wins
# 0                       0.0                         NaN        1.0
# 1                       0.0                         NaN        1.0
# 2                       0.0                         NaN        1.0
# 3                       0.0                         NaN        0.0
# 4                       0.0                         NaN        0.0

# %% [markdown]
# ## 3. Data Quality Checks

# %%
# Check for missing values
missing = df.isnull().sum()
missing = missing[missing > 0]
print("Columns with missing values:")
print(missing.sort_values(ascending=False))
# Out:
# Columns with missing values:
# q1_time                         25873
# q2_time                         25873
# q3_time                         25873
# time                            17438
# fastest_lap_rank                16887
# driver_abbreviation             15229
# qualifying_position             15023
# driver_championship_position     6990
# team_championship_position       5114
# team_championship_points          328
# team_wins                         328
# dtype: int64

# %%
# Check Qualifying Data Consistency
# Q1/Q2/Q3 times should be present for modern era races
recent_races = df[df['season_year'] >= 2023]
print("\nMissing Qualifying info for 2023+ seasons:")
print(recent_races[['q1_time', 'q2_time', 'q3_time']].isnull().sum())
# Out:
# Missing Qualifying info for 2023+ seasons:
# q1_time    1398
# q2_time    1398
# q3_time    1398
# dtype: int64

# %% [markdown]
# ## 4. Statistics

# %%
df.describe()
# Out:
#            round_id    circuit_id   season_year  round_number       team_id  \
# count  25873.000000  25873.000000  25873.000000  25873.000000  25873.000000
# mean     559.639663     31.627527   1992.484946      8.622077    117.847293
# std      325.101898     22.593345     20.556400      5.171198     65.785258
# min        1.000000      1.000000   1950.000000      1.000000      1.000000
# 25%      287.000000      7.000000   1977.000000      4.000000     59.000000
# 50%      543.000000     34.000000   1993.000000      8.000000    131.000000
# 75%      839.000000     52.000000   2010.000000     13.000000    177.000000
# max     1149.000000     77.000000   2025.000000     24.000000    211.000000
#
#           driver_id  qualifying_position          grid  finish_position  \
# count  25873.000000         10850.000000  25873.000000     25873.000000
# mean     624.251691            11.165069     11.711321        11.936729
# std      207.519981             6.238976      6.880082         6.878707
# min        1.000000             1.000000      0.000000         1.000000
# 25%      515.000000             6.000000      6.000000         6.000000
# 50%      685.000000            11.000000     11.000000        12.000000
# 75%      783.000000            16.000000     17.000000        17.000000
# max      864.000000            28.000000     34.000000        39.000000
#
#              status  laps_completed        points  fastest_lap_rank  \
# count  25873.000000    25873.000000  25873.000000       8986.000000
# mean       4.820083       48.908592      2.149402         10.317828
# std        5.902237       28.045228      4.524937          6.106787
# min        0.000000        0.000000      0.000000          0.000000
# 25%        0.000000       30.000000      0.000000          5.000000
# 50%        1.000000       53.000000      0.000000         10.000000
# 75%       11.000000       67.000000      2.000000         15.000000
# max       30.000000      200.000000     50.000000         24.000000
#
#        driver_championship_points  driver_championship_position   driver_wins  \
# count                25873.000000                  18883.000000  25873.000000
# mean                    20.676718                      9.800614      0.376802
# std                     46.346020                      5.985322      1.197644
# min                      0.000000                      1.000000      0.000000
# 25%                      0.000000                      5.000000      0.000000
# 50%                      4.000000                      9.000000      0.000000
# 75%                     19.000000                     14.000000      0.000000
# max                    575.000000                     29.000000     19.000000
#
#        team_championship_points  team_championship_position     team_wins
# count              25545.000000                20759.000000  25545.000000
# mean                  42.010785                    5.271786      0.846350
# std                   89.686718                    2.989903      2.008827
# min                    0.000000                    1.000000      0.000000
# 25%                    1.000000                    3.000000      0.000000
# 50%                   10.000000                    5.000000      0.000000
# 75%                   38.000000                    8.000000      1.000000
# max                  860.000000                   16.000000     21.000000

# %% [markdown]
# ## 5. Export Data
# Optionally save the loaded dataframe to CSV for manual inspection.

# %%
export_csv = True  # Set to True to export
output_path = "../data/processed/jolpica_eda_export.csv"

if export_csv:
    os.makedirs(os.path.dirname(output_path), exist_ok=True)
    df.to_csv(output_path, index=False)
    print(f"Data exported to {output_path}")
else:
    print("Export skipped")
# Out:
# Data exported to ../data/processed/jolpica_eda_export.csv
